# %% [markdown]
# # 01 - Puumala S : QC 10 genomes
# Source : NCBI (voir `data/raw/puumala_S_accessions.txt`). Fichiers raw gitignores, reproductible via `scripts/fetch_puumala_S.py`.

# %%
import sys
sys.path.insert(0, '../src')
from biox_virus_atlas.genomics import parse_fasta, qc_stats
import pandas as pd
seqs = parse_fasta('../data/raw/puumala_S_10.fasta')
q = qc_stats(seqs)
df = pd.DataFrame.from_dict(q, orient='index')
df
